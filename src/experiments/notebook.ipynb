# %%
import pandas as pd

df = pd.read_parquet("../../analytics/parquet/tas_s2_tas_deepseek_k1_20251126_013817.parquet")
print(df.columns)
df.head()
# Out:
# Index(['run_id', 'problem_id', 'dataset', 'phase', 'model', 'is_correct',
#        'true_answer', 'predicted_answer_raw', 'thesis_text', 'synthesis_text',
#        'has_error', 'prompt_tokens', 'completion_tokens', 'total_tokens'],
#       dtype='object')
#                                run_id  problem_id dataset   phase  \
# 0  s2_tas_deepseek_k1_20251126_013817  gsm8k-3082   gsm8k  tas_k1
# 1  s2_tas_deepseek_k1_20251126_013817  gsm8k-2184   gsm8k  tas_k1
# 2  s2_tas_deepseek_k1_20251126_013817  gsm8k-5897   gsm8k  tas_k1
# 3  s2_tas_deepseek_k1_20251126_013817  gsm8k-2437   gsm8k  tas_k1
# 4  s2_tas_deepseek_k1_20251126_013817  gsm8k-6330   gsm8k  tas_k1
#
#            model  is_correct true_answer predicted_answer_raw  \
# 0  deepseek-chat        True          16                   16
# 1  deepseek-chat        True          19                   19
# 2  deepseek-chat        True         196                  196
# 3  deepseek-chat        True           4                    4
# ...
